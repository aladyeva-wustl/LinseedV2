# %%
import yaml
import pandas as pd
import os
import re
import shutil

# %%
CONFIGS_PATH = "/Users/aladyeva.e/Dropbox (ArtyomovLab)/Deconvolution/nnls_d/configs"
ANALYSIS_NAME = "hnsc_male_hk_cc_8000_random_centered"

# %%
runs_df = pd.read_csv(os.path.join(CONFIGS_PATH,ANALYSIS_NAME,"runs.csv"))

# %%
runs_df.head()
# Out:
#       dataset                 path  cell_types  top_genes  global_iterations  \
# 0  HNSC_HK_CC  HNSC_HK_CC/8000/ct3           3       8000              10000
# 1  HNSC_HK_CC  HNSC_HK_CC/8000/ct4           4       8000              10000
# 2  HNSC_HK_CC  HNSC_HK_CC/8000/ct5           5       8000              10000
# 3  HNSC_HK_CC  HNSC_HK_CC/8000/ct6           6       8000              10000
# 4  HNSC_HK_CC  HNSC_HK_CC/8000/ct7           7       8000              10000
#
#    coef_der_X  coef_der_Omega  coef_hinge_H  coef_hinge_W  coef_pos_D_h  \
# 0     0.00001    1.000000e-09            10             5          0.01
# 1     0.00001    1.000000e-09            10             5          0.01
# 2     0.00001    1.000000e-09            10             5          0.01
# 3     0.00001    1.000000e-09            10             5          0.01
# 4     0.00001    1.000000e-09            10             5          0.01
#
#    coef_pos_D_w             analysis_name         inits/path  \
# 0          0.01  hnsc_male_hk_cc_8000_ct3  /app/config/inits
# 1          0.01  hnsc_male_hk_cc_8000_ct4  /app/config/inits
# 2          0.01  hnsc_male_hk_cc_8000_ct5  /app/config/inits
# 3          0.01  hnsc_male_hk_cc_8000_ct6  /app/config/inits
# 4          0.01  hnsc_male_hk_cc_8000_ct7  /app/config/inits
#
#                     data/path
# 0  /app/config/HNSC_HK_CC.rds
# 1  /app/config/HNSC_HK_CC.rds
# 2  /app/config/HNSC_HK_CC.rds
# 3  /app/config/HNSC_HK_CC.rds
# 4  /app/config/HNSC_HK_CC.rds

# %%
for index, row in runs_df.iterrows():
    yaml_config = {(k.split('/')[0] if '/' in k else k):({k.split('/')[1]:v} if '/' in k else v) 
                   for k,v in row.to_dict().items()}
    with open("{}.yml".format(row['analysis_name']), 'w+') as file:
        documents = yaml.dump(yaml_config, file)

# %%
analysis_names = list()
for path_,folders_,files_ in os.walk('/Users/aladyeva.e/Dropbox (ArtyomovLab)/Deconvolution/oldLinseed/data'):
    for file_ in files_:
        if re.compile('.rds$').search(file_):
            if 'norm' not in file_:
                new_filename = "{}_{}".format(path_.split("/")[-1],".".join(file_.split('.')[:-1]))
                analysis_names.append(new_filename)
                #shutil.copy(os.path.join(path_,file_),"/Users/aladyeva.e/Dropbox (ArtyomovLab)/Deconvolution/nnls_d/configs/LBL_SIMULATION_VCA/{}.rds".format(new_filename))
                #shutil.copy(os.path.join(path_,file_),"/Users/aladyeva.e/Dropbox (ArtyomovLab)/Deconvolution/nnls_d/configs/LBL_SIMULATION_CENTER/{}.rds".format(new_filename))

# %%
#./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a 
for name_ in analysis_names:
    print("./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a {}".format(name_))
# Out:
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_10_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_2_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_5_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_4_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_3_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_6_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_1_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_8_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_9_noise_deviation_4.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_4.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_4.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_5.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_2.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_3.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_4.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_2.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_3.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_2.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_3.20
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_2.60
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_4.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_3.80
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_3.40
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_2.00
# ./run_gradient_optim.sh -i 1 -c /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/config -l /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/logs -o /scratch1/fs1/martyomov/aladyevae/Deconvolution/02_2022/LBL_SIMULATION_CENTER/results -a seed_7_noise_deviation_4.60

# %%
#dataset = "LBL_SIMULATION_CENTER"
path = "LBL_SIMULATION_CENTER"
cell_types = 3
top_genes = 8000
global_iterations = 10000
coef_der_X = 1e-05
coef_der_Omega = 1e-08
coef_hinge_H = 10
coef_hinge_W = 5
coef_pos_D_h = 2
coef_pos_D_w = 2
inits_path = "/app/config/inits"

# %%
runs_df = pd.DataFrame({'dataset':analysis_names,
                           'path': path,
                           'cell_types': cell_types,
                           'top_genes': top_genes,
                           'global_iterations': global_iterations,
                           'coef_der_X': coef_der_X,
                           'coef_der_Omega': coef_der_Omega,
                           'coef_hinge_H': coef_hinge_H,
                           'coef_hinge_W': coef_hinge_W,
                           'coef_pos_D_h': coef_pos_D_h,
                           'coef_pos_D_w': coef_pos_D_w,
                           'inits/path': inits_path,
                           'analysis_name':analysis_names,
                           'data/path':['/app/config/{}.rds'.format(x) for x in analysis_names]})

# %%
runs_df.head()
# Out:
#                         dataset                   path  cell_types  top_genes  \
# 0  seed_10_noise_deviation_4.80  LBL_SIMULATION_CENTER           3       8000
# 1  seed_10_noise_deviation_4.40  LBL_SIMULATION_CENTER           3       8000
# 2  seed_10_noise_deviation_5.00  LBL_SIMULATION_CENTER           3       8000
# 3  seed_10_noise_deviation_2.20  LBL_SIMULATION_CENTER           3       8000
# 4  seed_10_noise_deviation_3.60  LBL_SIMULATION_CENTER           3       8000
#
#    global_iterations  coef_der_X  coef_der_Omega  coef_hinge_H  coef_hinge_W  \
# 0              10000     0.00001    1.000000e-08            10             5
# 1              10000     0.00001    1.000000e-08            10             5
# 2              10000     0.00001    1.000000e-08            10             5
# 3              10000     0.00001    1.000000e-08            10             5
# 4              10000     0.00001    1.000000e-08            10             5
#
#    coef_pos_D_h  coef_pos_D_w         inits/path  \
# 0             2             2  /app/config/inits
# 1             2             2  /app/config/inits
# 2             2             2  /app/config/inits
# 3             2             2  /app/config/inits
# 4             2             2  /app/config/inits
#
#                   analysis_name                                     data/path
# 0  seed_10_noise_deviation_4.80  /app/config/seed_10_noise_deviation_4.80.rds
# 1  seed_10_noise_deviation_4.40  /app/config/seed_10_noise_deviation_4.40.rds
# 2  seed_10_noise_deviation_5.00  /app/config/seed_10_noise_deviation_5.00.rds
# 3  seed_10_noise_deviation_2.20  /app/config/seed_10_noise_deviation_2.20.rds
# 4  seed_10_noise_deviation_3.60  /app/config/seed_10_noise_deviation_3.60.rds

# %%
SAVE_PATH = "/Users/aladyeva.e/Dropbox (ArtyomovLab)/Deconvolution/nnls_d/configs/LBL_SIMULATION_CENTER"

# %%
for index, row in runs_df.iterrows():
    yaml_config = {(k.split('/')[0] if '/' in k else k):({k.split('/')[1]:v} if '/' in k else v) 
                   for k,v in row.to_dict().items()}
    with open(os.path.join(SAVE_PATH,"{}.yml".format(row['analysis_name'])), 'w+') as file:
        documents = yaml.dump(yaml_config, file)

# %%
#dataset = "LBL_SIMULATION_VCA"
path = "LBL_SIMULATION_VCA"
cell_types = 3
top_genes = 8000
global_iterations = 10000
coef_der_X = 1e-05
coef_der_Omega = 1e-08
coef_hinge_H = 10
coef_hinge_W = 5
coef_pos_D_h = 2
coef_pos_D_w = 2
inits_path = "/app/config/inits"

# %%
runs_df = pd.DataFrame({'dataset':analysis_names,
                           'path': path,
                           'cell_types': cell_types,
                           'top_genes': top_genes,
                           'global_iterations': global_iterations,
                           'coef_der_X': coef_der_X,
                           'coef_der_Omega': coef_der_Omega,
                           'coef_hinge_H': coef_hinge_H,
                           'coef_hinge_W': coef_hinge_W,
                           'coef_pos_D_h': coef_pos_D_h,
                           'coef_pos_D_w': coef_pos_D_w,
                           'inits/path': inits_path,
                           'analysis_name':analysis_names,
                           'data/path':['/app/config/{}.rds'.format(x) for x in analysis_names]})

# %%
SAVE_PATH = "/Users/aladyeva.e/Dropbox (ArtyomovLab)/Deconvolution/nnls_d/configs/LBL_SIMULATION_VCA"

# %%
for index, row in runs_df.iterrows():
    yaml_config = {(k.split('/')[0] if '/' in k else k):({k.split('/')[1]:v} if '/' in k else v) 
                   for k,v in row.to_dict().items()}
    with open(os.path.join(SAVE_PATH,"{}.yml".format(row['analysis_name'])), 'w+') as file:
        documents = yaml.dump(yaml_config, file)
